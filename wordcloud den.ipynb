# %% [markdown]
# #wordcloud

# %%
import pandas as pd
df = pd.read_csv('text_alli.csv')
df
# Out:
#                                       UserName           Handle  \
# 0                               Media Selangor  @Media_Selangor
# 1     ð“¢ð“¾ð“»ð“°ð“ªð“»ð“¸ð“¾ð“½ð“®      @SurgaRoute
# 2                       Air Times News Network     @TheAirTimes
# 3                                      BERNAMA   @bernamadotcom
# 4                         Noor Hisham Abdullah        @DGHisham
# ...                                        ...              ...
# 1247                      Dr Irmohizam Ibrahim       @irmohizam
# 1248                      Dr Irmohizam Ibrahim       @irmohizam
# 1249                                 BeritaRTM       @beritartm
# 1250                             Bravo Project   @bravo_project
# 1251                             Bravo Project   @bravo_project
#
#                      Timestamp  \
# 0     2021-01-01T12:45:02.000Z
# 1     2021-01-01T12:44:02.000Z
# 2     2021-01-01T12:38:57.000Z
# 3     2021-01-01T12:36:24.000Z
# 4     2021-01-01T12:32:20.000Z
# ...                        ...
# 1247  2020-11-02T08:16:50.000Z
# 1248  2020-11-02T08:15:56.000Z
# 1249  2020-11-02T07:44:06.000Z
# 1250  2020-11-02T07:32:53.000Z
# 1251  2020-11-02T07:31:01.000Z
#
#                                                    text            Type
# 0     Selangor Journal | Bangkok to close schools fo...          Global
# 1     PKPP throughout the country continued until ma...  News, Malaysia
# 2     PKPP nationwide is extended due to significant...  News, Malaysia
# 3     #COVID-19 : Three new clusters detected today,...         Cluster
# 4     Pillars of Islam have 5 things and paying zaka...  News, Malaysia
# ...                                                 ...             ...
# 1247  Assalamualaikum & hi everyone! In the midst of...  News, Malaysia
# 1248  Assalamualaikum and greetings all. I hope you ...  News, Malaysia
# 1249  November 2 – Senator Ras Ras Special Officer A...  News, Malaysia
# 1250  He did not give up the opportunity to help fro...  News, Malaysia
# 1251  [COVID 19 VOLUNTEERS IN SABAH]\n\nFollowing th...  News, Malaysia
#
# [1252 rows x 5 columns]

# %%
text_count_df = df.groupby(['Type']).count()
text_count_df
# Out:
#                 UserName  Handle  Timestamp  text
# Type
# Cases                 91      90         92    92
# Cluster               30      30         30    30
# Deaths                49      49         49    49
# Entertainment         13      13         13    13
# Global                70      70         70    70
# News, Malaysia       917     922        923   924
# Politic                3       3          3     3
# Vaccine               71      71         71    71

# %%
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt
tags = ''
for index, row in df.iterrows():
    tags = tags + ' ' + row['text']
    
stopwords = set(STOPWORDS)
wordcloud_tac_repro = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stopwords, 
                min_font_size = 10).generate(tags) 
             
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud_tac_repro) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
